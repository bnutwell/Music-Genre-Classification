# %% [markdown]
# Import relevant libraries

# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
import soundfile as sf
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
import sklearn.preprocessing
from sklearn import svm, metrics
from statistics import mean
import numpy as np
import scipy.stats
import scipy.signal
import pandas as pd
import os
from scipy.stats import skew, kurtosis
import elm
from scipy.signal import butter,filtfilt
import seaborn as sns

import MusicUtilities as MU

# %% [markdown]
# Sample code to extract features from one audio file

# %%
import MusicUtilities as MU
# sample feature extraction
audio_path2 = 'GTZAN_data\\metal\\metal.00008.wav'
x, sr = librosa.load(audio_path2,sr=22050)

mfccs = MU.get_mfcc_features(x,sr)
ecfzs = MU.get_ecfz_features(x,sr)
stps = MU.get_stp_features(x,sr)
bfs = MU.get_beat_features(x,sr)
data = np.concatenate((mfccs,ecfzs,bfs,stps))

print("Shape of data features", data.shape)
print(ecfzs)
# Out:
# Shape of data features (169,)
# [0.058365826, 0.0142668905, 0.5446262936999839, -0.2582045378000184, 2966.002257457456, 923.240232595007, 1.0015803328004498, 0.9898759637640251, 1.1766737, 1.196811, 3.472689007797881, 14.717101964636598, 0.14056155742459397, 0.07107613399009521, 1.5224673298074614, 3.00068173245017, 2759.0013961515715, 532.1444167520538, 0.19584419304701403, -0.59982435446374, 6189.363682297709, 1800.2206519858933, 0.3323325863826684, -0.965678879457351, 8490.102335139936, 1487.3547550332532, -0.4916333274554118, -0.5572161483581439, 0.04424393, 0.053265367, 1.9058387041362435, 4.093275366333109, 21.749356399229818, 4.376601262250094, 1.4396686222783033, 4.399901266233924]

# %% [markdown]
# Code to extract all the features once for all files (Takes ~20min for all features)

# %%
# set full list of features to create
feat_dict = {'MFCC':False,
             'ECFZ':True,
             'BeatHist':False,
             'STP':False}
# Uncomment the item below to run the feature extraction
#success = MU.create_feature_files(feat_dict)

# %% [markdown]
# Load the feature data from CSV files

# %%
# Load the full feature set of data
feat_list = ['MFCC','ECFZ','BeatHist','STP']  
feat_dict = {f:True for f in feat_list}
data = MU.get_music_features(feat_dict)
print("Shape of music data:",data.shape)

# Load the class labels
label_data = pd.read_csv("features\\musiclabels.csv",header=None)
label_array = np.array(label_data[0]).flatten()

# Scale the data
scaler = sklearn.preprocessing.StandardScaler()
data_scaled = scaler.fit_transform(data)

# Split the data into train/test sets
Xtrain, Xtest, Ytrain, Ytest = train_test_split(data_scaled, label_array.T, test_size=0.2, random_state=1)
# Out:
# Shape of music data: (999, 169)

# %% [markdown]
# Initial model tuning and parameter setting with all data

# %%
#Tuning the number of neighbors for KNN
knn = KNeighborsClassifier()
#List of values to test 
parameter = {"n_neighbors":[3, 5, 7, 9, 11, 13, 15]}
grid_search = GridSearchCV(knn, parameter, cv=5)
#Fit model to the training data
knn_model = grid_search.fit(Xtrain, Ytrain)
# Print the best hyperparameter value found by the grid search
print(grid_search.best_params_)
# Out:
# {'n_neighbors': 9}

# %%
#Tuning the SVM (regularization parameter C)
svm = LinearSVC(max_iter=10000)
# Define the values of the regularization parameter C to test 
parameters = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
svm_grid_search = GridSearchCV(svm, parameters, cv=5)
svm_grid_search.fit(Xtrain, Ytrain)
# Print the best hyperparameter value 
print(svm_grid_search.best_params_)
# Out:
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\.venv\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\.venv\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\.venv\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\.venv\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\.venv\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\.venv\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# {'C': 0.01}
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\.venv\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#Tuning non-linear (kernel) SVM
kern_svm = SVC()
# Define the hyperparameters to tune
parameters = {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'kernel': ['linear', 'poly', 'rbf', 'sigmoid']}
kern_svm_grid_search = GridSearchCV(kern_svm, parameters, cv=5)
#Fit to data
kern_svm_grid_search.fit(Xtrain, Ytrain)
# Print the best hyperparameter values 
print(kern_svm_grid_search.best_params_)
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
#Tuning Neural Networks 
# define the parameter grid
parameters = {
    'hidden_layer_sizes': [(67,), (68,), (69,), (70,), (71,), (72,), (70,70), (71,71)],
    #'activation': ['logistic', 'tanh', 'relu'],
    #'solver': ['sgd', 'adam'],
    #'alpha': [0.0001, 0.001, 0.01, 0.1],
    'learning_rate': ['constant', 'adaptive'],
}

# create the MLPClassifier
NN = MLPClassifier(max_iter=10000)

# create the GridSearchCV object
grid = GridSearchCV(NN, parameters, cv=5, scoring='accuracy')

# fit the GridSearchCV object to the data
grid.fit(Xtrain, Ytrain)

# print the best hyperparameters and corresponding accuracy score
print("Best parameters: ", grid.best_params_)
print("Best accuracy: ", grid.best_score_)
# Out:
# Best parameters:  {'hidden_layer_sizes': (69,), 'learning_rate': 'constant'}
# Best accuracy:  0.720880503144654

# %% [markdown]
# Train and run ELM (Extreme Learning Machine) classifier
#
# (not sklearn so it requires a different run structure)

# %%
genredict = {'blues':0,
             'classical':1,
             'country':2,
             'disco':3,
             'hiphop':4,
             'jazz':5,
             'metal':6,
             'pop':7,
             'reggae':8,
             'rock':9}

# create an ELM (Extreme Learning Machine) classifier
# first add the class labels as the first column of the data
Yt3 = np.array([genredict[g] for g in Ytrain]).reshape((799,1))
elmdata = np.concatenate((Yt3,Xtrain),axis=1)
# then run the ELM model
params=['sigmoid',1,500,False]
elmk = elm.ELMRandom(params)
#elmk.search_param(elmdata,cv='kfold',of='accuracy',eval=10)
elm_result = elmk.train(elmdata)
elm_accuracy = elm_result.get_accuracy()
print("Testing accuracy of ELM", elm_accuracy)
print("#######################################################")
# Out:
# Testing accuracy of ELM 0.27784730913642053
# #######################################################

# %% [markdown]
# Set up Classification Models

# %%
# Build DOE matrix of feature sets to try
doe_matrix = pd.read_csv("DOE_matrix.csv",index_col=0)

# Load the class labels
label_data = pd.read_csv("features\\musiclabels.csv",header=None)
label_array = np.array(label_data).flatten()

# Establish other parameters and tuning options
n_cv = 10
feat_list = [f for f in doe_matrix.columns]

modelnames = ["KNN", "Logistic Regression", "SVM", "Kernel SVM", "Bagging_kernSVM", "Neural Networks", "Bagging NN", 
              "Random Forest", "Boosted Decision Tree", "Boosted Kernel SVM" ]
classifiers = [KNeighborsClassifier(grid_search.best_params_['n_neighbors']),
               LogisticRegression(max_iter=10000),
               LinearSVC(C=svm_grid_search.best_params_['C'], max_iter=10000),
               SVC(C=kern_svm_grid_search.best_params_['C'], kernel=kern_svm_grid_search.best_params_['kernel'], max_iter=10000),
               BaggingClassifier(SVC(C=kern_svm_grid_search.best_params_['C'], kernel=kern_svm_grid_search.best_params_['kernel'], 
                                     max_iter=10000), n_estimators=10),
               MLPClassifier(hidden_layer_sizes=(72, ),  activation='relu', solver='adam', alpha=0.0001, 
                             learning_rate='constant',max_iter=10000),
               BaggingClassifier(estimator=MLPClassifier(hidden_layer_sizes=(72, ),  activation='relu', solver='adam', 
                                                              alpha=0.0001, learning_rate='constant',max_iter=10000), 
                                 n_estimators=10, max_samples=0.5),         
               RandomForestClassifier(n_estimators=100),
               AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=7),                                                     
                                  n_estimators=70),
               AdaBoostClassifier(estimator=SVC(C=kern_svm_grid_search.best_params_['C'], kernel=kern_svm_grid_search.best_params_['kernel'], 
                                                max_iter=10000),                                                     
                                  n_estimators=70, algorithm='SAMME')
               
              ]
cf_dict = dict(zip(modelnames, classifiers))

# %% [markdown]
# Run one trial of all models against DOE combination of feature-sets

# %%
# for each DOE combination
for d in range(1,doe_matrix.shape[0]+1):

  results = []
  # set the desired features
  feat_dict = {f:bool(doe_matrix[f][d]) for f in feat_list}
  print("DOE run",d,feat_dict)

  # Load features according to DOE
  data = MU.get_music_features(feat_dict)
  print("Shape of music data:",data.shape)

  # Scale the data
  scaler = sklearn.preprocessing.StandardScaler()
  data_scaled = scaler.fit_transform(data)

  # Split the data into train/test sets
  Xtrain, Xtest, Ytrain, Ytest = train_test_split(data_scaled, label_array.T, test_size=0.2, random_state=1+d)
  data_array = [Xtrain, Xtest, Ytrain, Ytest]

  # Train models and analyze the results:
  #   Mean accuracy of each model + feature-set
  for model in modelnames:
    _, _, accy = MU.run_classification(model,cf_dict,data_array,verbose=False)
    results.append(accy)
    print("Accuracy of", model, "is", round(accy * 100, 1), "%")

  bestaccy_ind = np.argmax(results)
  bestaccy = results[bestaccy_ind]
  bestmodel = modelnames[bestaccy_ind]
  print("DOE run",d,"best accuracy:",round(bestaccy*100,1),"% with model",bestmodel)

  # Report summarized metrics
  # Print the confusion matrix for the best model
  clf = cf_dict[bestmodel]
  clf.fit(Xtrain,Ytrain)
  predicted = clf.predict(Xtest)
  print("Confusion matrix for best model:")
  cf_matrix = metrics.confusion_matrix(Ytest, predicted)
  sns.heatmap(cf_matrix, annot=True, cmap='Blues')
  plt.show()
# Out:
# DOE run 1 {'MFCC': False, 'ECFZ': False, 'BeatHist': True, 'STP': True}
# Skipping feature MFCC as requested
# Skipping feature ECFZ as requested
# Shape of music data: (999, 19)
# Accuracy of KNN is 27.5 %
# Accuracy of Logistic Regression is 27.5 %
# Accuracy of SVM is 23.0 %
# Accuracy of Kernel SVM is 39.0 %
# Accuracy of Bagging_kernSVM is 33.5 %
# Accuracy of Neural Networks is 34.5 %
# Accuracy of Bagging NN is 39.0 %
# Accuracy of Random Forest is 38.0 %
# Accuracy of Boosted Decision Tree is 33.5 %
# Accuracy of Boosted Kernel SVM is 17.5 %
# DOE run 1 best accuracy: 39.0 % with model Kernel SVM
# Confusion matrix for best model:
# DOE run 2 {'MFCC': True, 'ECFZ': False, 'BeatHist': True, 'STP': False}
# Skipping feature ECFZ as requested
# Skipping feature STP as requested
# Shape of music data: (999, 120)
# Accuracy of KNN is 53.5 %
# Accuracy of Logistic Regression is 62.0 %
# Accuracy of SVM is 60.5 %
# Accuracy of Kernel SVM is 64.5 %
# Accuracy of Bagging_kernSVM is 65.5 %
# Accuracy of Neural Networks is 66.0 %
# Accuracy of Bagging NN is 61.0 %
# Accuracy of Random Forest is 61.0 %
# Accuracy of Boosted Decision Tree is 54.5 %
# Accuracy of Boosted Kernel SVM is 5.5 %
# DOE run 2 best accuracy: 66.0 % with model Neural Networks
# Confusion matrix for best model:
# DOE run 3 {'MFCC': True, 'ECFZ': False, 'BeatHist': False, 'STP': True}
# Skipping feature ECFZ as requested
# Skipping feature BeatHist as requested
# Shape of music data: (999, 127)
# Accuracy of KNN is 54.5 %
# Accuracy of Logistic Regression is 66.5 %
# Accuracy of SVM is 65.0 %
# Accuracy of Kernel SVM is 68.5 %
# Accuracy of Bagging_kernSVM is 71.0 %
# Accuracy of Neural Networks is 64.5 %
# Accuracy of Bagging NN is 64.5 %
# Accuracy of Random Forest is 63.0 %
# Accuracy of Boosted Decision Tree is 54.5 %
# Accuracy of Boosted Kernel SVM is 26.5 %
# DOE run 3 best accuracy: 71.0 % with model Bagging_kernSVM
# Confusion matrix for best model:
# DOE run 4 {'MFCC': False, 'ECFZ': True, 'BeatHist': True, 'STP': False}
# Skipping feature MFCC as requested
# Skipping feature STP as requested
# Shape of music data: (999, 42)
# Accuracy of KNN is 54.5 %
# Accuracy of Logistic Regression is 63.0 %
# Accuracy of SVM is 55.5 %
# Accuracy of Kernel SVM is 67.5 %
# Accuracy of Bagging_kernSVM is 68.0 %
# Accuracy of Neural Networks is 68.5 %
# Accuracy of Bagging NN is 66.0 %
# Accuracy of Random Forest is 65.0 %
# Accuracy of Boosted Decision Tree is 69.5 %
# Accuracy of Boosted Kernel SVM is 24.0 %
# DOE run 4 best accuracy: 69.5 % with model Boosted Decision Tree
# Confusion matrix for best model:
# DOE run 5 {'MFCC': True, 'ECFZ': True, 'BeatHist': False, 'STP': False}
# Skipping feature BeatHist as requested
# Skipping feature STP as requested
# Shape of music data: (999, 150)
# Accuracy of KNN is 62.5 %
# Accuracy of Logistic Regression is 68.5 %
# Accuracy of SVM is 68.5 %
# Accuracy of Kernel SVM is 74.0 %
# Accuracy of Bagging_kernSVM is 71.0 %
# Accuracy of Neural Networks is 74.5 %
# Accuracy of Bagging NN is 73.0 %
# Accuracy of Random Forest is 72.0 %
# Accuracy of Boosted Decision Tree is 64.5 %
# Accuracy of Boosted Kernel SVM is 22.0 %
# DOE run 5 best accuracy: 74.5 % with model Neural Networks
# Confusion matrix for best model:
# DOE run 6 {'MFCC': True, 'ECFZ': True, 'BeatHist': True, 'STP': True}
# Shape of music data: (999, 169)
# Accuracy of KNN is 62.5 %
# Accuracy of Logistic Regression is 67.5 %
# Accuracy of SVM is 64.5 %
# Accuracy of Kernel SVM is 75.5 %
# Accuracy of Bagging_kernSVM is 72.5 %
# Accuracy of Neural Networks is 67.0 %
# Accuracy of Bagging NN is 65.5 %
# Accuracy of Random Forest is 65.0 %
# Accuracy of Boosted Decision Tree is 68.0 %
# Accuracy of Boosted Kernel SVM is 16.5 %
# DOE run 6 best accuracy: 75.5 % with model Kernel SVM
# Confusion matrix for best model:
# DOE run 7 {'MFCC': False, 'ECFZ': True, 'BeatHist': False, 'STP': True}
# Skipping feature MFCC as requested
# Skipping feature BeatHist as requested
# Shape of music data: (999, 49)
# Accuracy of KNN is 56.5 %
# Accuracy of Logistic Regression is 70.5 %
# Accuracy of SVM is 63.5 %
# Accuracy of Kernel SVM is 68.0 %
# Accuracy of Bagging_kernSVM is 67.5 %
# Accuracy of Neural Networks is 62.5 %
# Accuracy of Bagging NN is 64.5 %
# Accuracy of Random Forest is 71.0 %
# Accuracy of Boosted Decision Tree is 65.0 %
# Accuracy of Boosted Kernel SVM is 19.0 %
# DOE run 7 best accuracy: 71.0 % with model Random Forest
# Confusion matrix for best model:
# DOE run 8 {'MFCC': True, 'ECFZ': True, 'BeatHist': True, 'STP': False}
# Skipping feature STP as requested
# Shape of music data: (999, 156)
# Accuracy of KNN is 68.0 %
# Accuracy of Logistic Regression is 72.5 %
# Accuracy of SVM is 75.0 %
# Accuracy of Kernel SVM is 80.0 %
# Accuracy of Bagging_kernSVM is 78.5 %
# Accuracy of Neural Networks is 76.0 %
# Accuracy of Bagging NN is 75.5 %
# Accuracy of Random Forest is 70.0 %
# Accuracy of Boosted Decision Tree is 71.0 %
# Accuracy of Boosted Kernel SVM is 6.0 %
# DOE run 8 best accuracy: 80.0 % with model Kernel SVM
# Confusion matrix for best model:

# %% [markdown]
# Perform Cross-Validation for all models
# against DOE run 8:  All Feature-Sets except STP

# %%
# Performing cross-validation for the DOE setup 8
from sklearn.model_selection import cross_val_score

# for DOE combination 8
d = doe_matrix.shape[0]

results = {}
# set the desired features
feat_dict = {f:bool(doe_matrix[f][d]) for f in feat_list}
print("DOE run",d,feat_dict)

# Load features according to DOE
data = MU.get_music_features(feat_dict)
print("Shape of music data:",data.shape)

# Scale the data
scaler = sklearn.preprocessing.StandardScaler()
data_scaled = scaler.fit_transform(data)

# Split the data into train/test sets
Xtrain, Xtest, Ytrain, Ytest = train_test_split(data_scaled, label_array.T, test_size=0.2, random_state=1+d)

# Train models in CV loops
for model in modelnames:
    clf = cf_dict[model]
    cv_scores = cross_val_score(clf, Xtrain, Ytrain, cv=20)
    results[model] = cv_scores.tolist()
    print("Average accuracy of", model, "is", round(cv_scores.mean() * 100, 1), "%")

bestaccy_ind = np.argmax([np.mean(v) for v in results.values()])
bestaccy = np.mean(results[modelnames[bestaccy_ind]])
bestmodel = modelnames[bestaccy_ind]
print("DOE run",d,"best accuracy:",round(bestaccy*100,1),"% with model",bestmodel)

# Print the confusion matrix for the best model
clf = cf_dict[bestmodel]
clf.fit(Xtrain,Ytrain)
predicted = clf.predict(Xtest)
print("Confusion matrix for best model:")
cf_matrix = metrics.confusion_matrix(Ytest, predicted)
sns.heatmap(cf_matrix, annot=True, cmap='Blues')
plt.show()

# Plot box plots for each model
labels = ['KNN','LogReg','SVM','Kernel-SVM','Bag_K-SVM','NeuralNet','Bag_NN','RF']
fig, ax = plt.subplots(figsize=(8,4))
ax.boxplot(list(results.values())[:8])
ax.set_xticklabels(labels,rotation=-45)
ax.set_ylabel("Classification Accuracy")
ax.set_ybound(0,1)
ax.set_title("Model CV Accuracy for DOE Setup 8")
plt.show()
# Out:
# DOE run 8 {'MFCC': True, 'ECFZ': True, 'BeatHist': True, 'STP': False}
# Skipping feature STP as requested
# Shape of music data: (999, 156)
# Average accuracy of KNN is 61.8 %
# Average accuracy of Logistic Regression is 66.1 %
# Average accuracy of SVM is 68.2 %
# Average accuracy of Kernel SVM is 74.3 %
# Average accuracy of Bagging_kernSVM is 72.0 %
# Average accuracy of Neural Networks is 68.2 %
# Average accuracy of Bagging NN is 67.6 %
# Average accuracy of Random Forest is 67.2 %
# Average accuracy of Boosted Decision Tree is 64.4 %
# Average accuracy of Boosted Kernel SVM is 11.9 %
# DOE run 8 best accuracy: 74.3 % with model Kernel SVM
# Confusion matrix for best model:

# %% [markdown]
# DOE run 6 Cross-Validation:  All feature-sets

# %%
# for DOE combination 6
d = 6

results = {}
# set the desired features
feat_dict = {f:bool(doe_matrix[f][d]) for f in feat_list}
print("DOE run",d,feat_dict)

# Load features according to DOE
data = MU.get_music_features(feat_dict)
print("Shape of music data:",data.shape)

# Scale the data
scaler = sklearn.preprocessing.StandardScaler()
data_scaled = scaler.fit_transform(data)

# Split the data into train/test sets
Xtrain, Xtest, Ytrain, Ytest = train_test_split(data_scaled, label_array.T, test_size=0.2, random_state=1+d)

# Train models in CV loops
for model in modelnames:
    clf = cf_dict[model]
    cv_scores = cross_val_score(clf, Xtrain, Ytrain, cv=10)
    results[model] = cv_scores.tolist()
    print("Average accuracy of", model, "is", round(cv_scores.mean() * 100, 1), "%")


bestaccy_ind = np.argmax([np.mean(v) for v in results.values()])
bestaccy = np.mean(results[modelnames[bestaccy_ind]])
bestmodel = modelnames[bestaccy_ind]
print("DOE run",d,"best accuracy:",round(bestaccy*100,1),"% with model",bestmodel)

# Print the confusion matrix for the best model
clf = cf_dict[bestmodel]
clf.fit(Xtrain,Ytrain)
predicted = clf.predict(Xtest)
print("Confusion matrix for best model:")
cf_matrix = metrics.confusion_matrix(Ytest, predicted)
sns.heatmap(cf_matrix, annot=True, cmap='Blues')
plt.show()


# Plot box plots for each model
labels = ['KNN','LogReg','SVM','Kernel-SVM','Bag_K-SVM','NeuralNet','Bag_NN','RF']
fig, ax = plt.subplots(figsize=(8,4))
ax.boxplot(list(results.values())[:8])
ax.set_xticklabels(labels,rotation=-45)
ax.set_ylabel("Classification Accuracy")
ax.set_ybound(0,1)
ax.set_title("Model CV Accuracy for DOE Setup 8")
plt.show()
# Out:
# DOE run 6 {'MFCC': True, 'ECFZ': True, 'BeatHist': True, 'STP': True}
# Shape of music data: (999, 169)
# Average accuracy of KNN is 61.5 %
# Average accuracy of Logistic Regression is 70.8 %
# Average accuracy of SVM is 72.1 %
# Average accuracy of Kernel SVM is 72.7 %
# Average accuracy of Bagging_kernSVM is 72.0 %
# Average accuracy of Neural Networks is 71.0 %
# Average accuracy of Bagging NN is 70.1 %
# Average accuracy of Random Forest is 67.3 %
# Average accuracy of Boosted Decision Tree is 64.2 %
# Average accuracy of Boosted Kernel SVM is 16.1 %
# DOE run 6 best accuracy: 72.7 % with model Kernel SVM
# Confusion matrix for best model:

# %% [markdown]
# Extract Features for Unknown Sample Files

# %%
unknowns = librosa.util.find_files('Genre_Samples_Converted')
print(unknowns[1])

# set full list of features to create
feat_dict = {'MFCC':True,
             'ECFZ':True,
             'BeatHist':True,
             'STP':True}
# Uncomment the item below to run the feature extraction
success = MU.create_feature_files2(unknowns,feat_dict,verbose=True)
# Out:
# c:\GTMS Projects\ISYE6740 CDA\ISYE6740_Music_Analysis\Genre_Samples_Converted\Blues\02 Before You Accuse Me.Wav
# 01 He Don't Play Nothin' But The Blues.Wav
# Processing file: Blues 01 He Don't Play Nothin' But The Blues.Wav
# 0.18705736 2122.000047925517 1.1849723 0.10242677236323967
# 2319.6570118115737 4428.124008471025 7180.589884907807 0.014736434 20.380985663236263
# 02 Before You Accuse Me.Wav
# Processing file: Blues 02 Before You Accuse Me.Wav
# 0.12329535 2484.8969012409934 1.1966155 0.12822060970396332
# 2482.474111335477 5304.797662920224 7733.383427127043 0.0360153 19.973207884179402
# 03 Back Door Santa.Wav
# Processing file: Blues 03 Back Door Santa.Wav
# 0.21813215 2033.318003025672 1.4627424 0.08994316186797753
# 2279.6995756654346 4268.9889725245785 6988.326465392381 0.012534234 20.645875918528574
# 09 (Let Me Up) I've Had Enough.Wav
# Processing file: Blues 09 (Let Me Up) I've Had Enough.Wav
# 0.17124145 2378.6847170847855 1.2637806 0.11219812201644272
# 2536.036992884805 5211.079319113552 7963.149075649752 0.026749583 21.595346409506856
# 1-10 Worried Down With The Blues.Wav
# Processing file: Blues 1-10 Worried Down With The Blues.Wav
# 0.21367481 1715.1630598649358 1.2619209 0.07581524297709247
# 2069.80377490102 3469.4995470920426 6289.040123958403 0.009138457 21.550704081509373
# 03 Vivaldi_ Gloria - Laudamus Te.Wav
# Processing file: Classical 03 Vivaldi_ Gloria - Laudamus Te.Wav
# 0.035401385 1215.9892549891024 1.203158 0.07226336705202312
# 1356.8744391433338 2220.3559654985547 3905.31933029263 0.0008696514 16.943797550822435
# 04 Mozart_ The Marriage Of Figaro - E Susanna Non Vien! ... Dove Sono.Wav
# Processing file: Classical 04 Mozart_ The Marriage Of Figaro - E Susanna Non Vien! ... Dove Sono.Wav
# 0.045503113 1366.8609144821598 1.0194775 0.08396236232069672
# 1365.4406221610366 2418.8446939803525 3810.5099819185994 0.0017018702 18.428323870599435
# 05 Dvorák_ Rondo For Cello And Orchestra In G Minor, Op. 94.Wav
# Processing file: Classical 05 Dvorák_ Rondo For Cello And Orchestra In G Minor, Op. 94.Wav
# 0.018052075 1111.0692912775944 1.0239657 0.057541707318158095
# 1434.8760710343706 2090.040730570317 3878.6830274401273 0.00076191494 19.674392467858258
# 07 Partita No. 2 d-moll, BWV 1004. III Sarabanda.Wav
# Processing file: Classical 07 Partita No. 2 d-moll, BWV 1004. III Sarabanda.Wav
# 0.03644328 1935.4619608657877 1.1093369 0.10782452668602684
# 1697.7760629513975 3414.9979658160173 5096.803784287069 0.02128163 23.995935003364377
# 14 Bach_ Magnificat - Et Exsultavit.Wav
# Processing file: Classical 14 Bach_ Magnificat - Et Exsultavit.Wav
# 0.027847957 1134.3826186179 1.085928 0.06496490225661249
# 1332.1790878854836 2079.46890544709 3711.9574406406846 0.00078068365 16.724243974182208
# 04 Satin Doll.Wav
# Processing file: Jazz 04 Satin Doll.Wav
# 0.07412232 1379.217689181201 1.258516 0.06968786465877998
# 1808.5135595720526 2752.387332225525 5305.42011049161 0.0017762914 24.93218398068552
# 05 How High The Moon.Wav
# Processing file: Jazz 05 How High The Moon.Wav
# 0.06916259 2022.966891822089 1.2328559 0.08794935994781196
# 2187.4834859516877 4293.8521480531745 6744.102592450312 0.012151205 28.59347273396328
# 06 Minor Swing.Wav
# Processing file: Jazz 06 Minor Swing.Wav
# 0.055252522 1367.6177081058963 1.5473704 0.06130327553550659
# 1821.6775836488755 2722.941435150596 5334.922035278415 0.0032629538 17.98116220667069
# 08 The Oneness Of Two (In Three).Wav
# Processing file: Jazz 08 The Oneness Of Two (In Three).Wav
# 0.08692107 1914.1136122836954 1.1868908 0.0656884301837526
# 2474.573979158357 4396.572427588282 7731.2044872307715 0.007971927 21.00276909886208
# 12 Take The 'A' Train.Wav
# Processing file: Jazz 12 Take The 'A' Train.Wav
# 0.044345547 2300.6916257064286 1.2274214 0.09139970730694416
# 2574.486170679143 5167.641074045265 8042.544613030301 0.012287707 20.8166053642543
# 01 Burning Times.Wav
# Processing file: Metal 01 Burning Times.Wav
# 0.20233408 2680.3276797338153 1.2208614 0.1265098043509291
# 2633.7402495767315 5514.322934407603 8426.401972406864 0.03810396 23.612983007756664
# 02 Cloud Connected.Wav
# Processing file: Metal 02 Cloud Connected.Wav
# 0.26396745 2706.108850752019 1.0922184 0.13348447729872212
# 2551.0199319345434 5524.853055999717 8188.362847610236 0.042020895 22.119904553233724
# 02 The Enemy Inside.Wav
# Processing file: Metal 02 The Enemy Inside.Wav
# 0.29450196 2467.680163773186 1.2032002 0.10561998622623954
# 2457.79095957726 5132.311667795257 7730.176189753014 0.02964135 25.14981349380977
# 02 The Motherload.Wav
# Processing file: Metal 02 The Motherload.Wav
# 0.31820476 2623.00384935847 1.0159318 0.13406035086679186
# 2455.450113209754 5273.069423127879 7790.670871365379 0.039319072 22.27913196032438
# 1-02 Only.Wav
# Processing file: Metal 1-02 Only.Wav
# 0.2500069 2445.645549547176 1.1124109 0.11040779670851614
# 2532.2667298403876 5188.632291090298 8076.393579323439 0.028040925 21.91489932442387
# 01 Rhythmeen.Wav
# Processing file: Rock 01 Rhythmeen.Wav
# 0.16538985 3133.5770542539653 1.1957867 0.14059372669070114
# 3020.9544913492996 6982.319396638799 9031.517945246456 0.050690737 21.311686235180662
# 01 The Silent Type.Wav
# Processing file: Rock 01 The Silent Type.Wav
# 0.17185181 2503.1716192786207 1.3204129 0.1156057058843819
# 2541.791560048916 5367.198413570985 7940.173760218336 0.038075704 24.553400266088598
# 02 Are You Gonna Be My Girl.Wav
# Processing file: Rock 02 Are You Gonna Be My Girl.Wav
# 0.23127997 2825.9529291681624 1.3636347 0.14753935923087358
# 2513.8058387407136 5611.840155317417 7946.438959280046 0.04107318 25.69811062644414
# 02 Thorazine Shuffle.Wav
# Processing file: Rock 02 Thorazine Shuffle.Wav
# 0.19803031 2052.2492156828157 1.4455702 0.0775180808600211
# 2349.6128778190223 4470.062321653275 7195.655171342077 0.016307378 23.26868650841365
# 07 She's Got Something To Say To Me.Wav
# Processing file: Rock 07 She's Got Something To Say To Me.Wav
# 0.26346266 2650.50235294804 1.0426931 0.14086076051201374
# 2406.560002622916 5244.681812696654 7639.2232752610125 0.03679793 22.901971100785588
# 04 This Is the Life.Wav
# Processing file: Unknown 04 This Is the Life.Wav
# 0.19010162 1991.2629500258824 1.0148375 0.08779471746051608
# 2221.71552872038 4261.758829141641 6839.856360266516 0.01603502 22.083789708742692
# 06 The Colour Of Love.Wav
# Processing file: Unknown 06 The Colour Of Love.Wav
# 0.15733092 1519.306922594997 1.2508497 0.060604919271734115
# 2131.331432473118 3145.262016684322 6573.950609110169 0.0066948184 19.911795390312133
# 1-09 Sco-Mule.Wav
# Processing file: Unknown 1-09 Sco-Mule.Wav
# 0.19129406 2027.0967324418796 1.4197826 0.09260959683762758
# 2214.966289061707 4268.8405572013335 6795.106887459106 0.016417684 22.66621928201424

# %% [markdown]
# Load Features for Unknown Sample Files

# %%
# Load the full feature set of data
feat_list = ['MFCC','ECFZ','BeatHist','STP']  
feat_dict = {f:True for f in feat_list}
v_data = MU.get_music_features2(feat_dict)
print("Shape of music data:",v_data.shape)

# Load the class labels
label_data = pd.read_csv("features2\\musiclabels2.csv",header=None)
Yvalid = np.array(label_data[0]).flatten()

# Scale the data
scaler = sklearn.preprocessing.StandardScaler()
Xvalid = scaler.fit_transform(v_data)
# Out:
# Shape of music data: (28, 169)

# %% [markdown]
# Estimate Genre for Unknown Files

# %%
unknowns = librosa.util.find_files('Genre_Samples_Converted')

# run each model against the new files
for model in ["SVM"]:
  clf = cf_dict[model]
  clf.fit(Xtrain,Ytrain)
  predicted = clf.predict(Xvalid)
  testing_accuracy = clf.score(Xvalid[:25], Yvalid[:25])

  for i in range(28):
    file = unknowns[i]
    pathsplit = file.split("\\")
    songfile = pathsplit[len(pathsplit)-1]
    print(i,"Actual:",Yvalid[i],"| Predicted:",predicted[i],'|',songfile[0:25])
  
  print("Accuracy of", model, "is", round(testing_accuracy * 100, 1), "%")

  cf_matrix = metrics.confusion_matrix(Yvalid[:25], predicted[:25])
  sns.heatmap(cf_matrix, annot=True, cmap='Blues')
  plt.show()
# Out:
# 0 Actual: blues | Predicted: jazz | 01 He Don't Play Nothin'
# 1 Actual: blues | Predicted: rock | 02 Before You Accuse Me.W
# 2 Actual: blues | Predicted: hiphop | 03 Back Door Santa.Wav
# 3 Actual: blues | Predicted: disco | 09 (Let Me Up) I've Had E
# 4 Actual: blues | Predicted: country | 1-10 Worried Down With Th
# 5 Actual: classical | Predicted: classical | 03 Vivaldi_ Gloria - Laud
# 6 Actual: classical | Predicted: classical | 04 Mozart_ The Marriage O
# 7 Actual: classical | Predicted: classical | 05 Dvorák_ Rondo For Cell
# 8 Actual: classical | Predicted: hiphop | 07 Partita No. 2 d-moll,
# 9 Actual: classical | Predicted: classical | 14 Bach_ Magnificat - Et
# 10 Actual: jazz | Predicted: jazz | 04 Satin Doll.Wav
# 11 Actual: jazz | Predicted: jazz | 05 How High The Moon.Wav
# 12 Actual: jazz | Predicted: reggae | 06 Minor Swing.Wav
# 13 Actual: jazz | Predicted: jazz | 08 The Oneness Of Two (In
# 14 Actual: jazz | Predicted: jazz | 12 Take The 'A' Train.Wav
# 15 Actual: metal | Predicted: metal | 01 Burning Times.Wav
# 16 Actual: metal | Predicted: metal | 02 Cloud Connected.Wav
# 17 Actual: metal | Predicted: metal | 02 The Enemy Inside.Wav
# 18 Actual: metal | Predicted: metal | 02 The Motherload.Wav
# 19 Actual: metal | Predicted: metal | 1-02 Only.Wav
# 20 Actual: rock | Predicted: disco | 01 Rhythmeen.Wav
# 21 Actual: rock | Predicted: disco | 01 The Silent Type.Wav
# 22 Actual: rock | Predicted: reggae | 02 Are You Gonna Be My Gi
# 23 Actual: rock | Predicted: reggae | 02 Thorazine Shuffle.Wav
# 24 Actual: rock | Predicted: country | 07 She's Got Something To
# 25 Actual: unknown | Predicted: country | 04 This Is the Life.Wav
# 26 Actual: unknown | Predicted: blues | 06 The Colour Of Love.Wav
# 27 Actual: unknown | Predicted: hiphop | 1-09 Sco-Mule.Wav
# Accuracy of SVM is 52.0 %
